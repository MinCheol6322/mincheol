# %% [markdown]
# # **Project 1: Classification of Time Series Data**

# %% [markdown]
# Name: Haneen Alsuradi
# NetID: hha243

# %% [markdown]
# In this project, I will use 1 dimensional convolotional network to perform classification on time series data. Data is taken from Kaggle competition [Surface Type Classification] found in the link below: https://www.kaggle.com/c/career-con-2019/overview

# %% [markdown]
# ## **Step 1: Data Preparation**

# %% [markdown]
# The first step is to import, view and prepare the data. We import the data saved in X_train.csv and y_train.csv. We split the data to train and test as advised. After that, we view the data using the head() command from pandas.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt

# read Kaggle datasets
X_train = pd.read_csv('C:\\data/X_train.csv')
y_train = pd.read_csv('C:\\data/y_train.csv')
# split X_train
samples = 20
time_series = 128
start_x = X_train.shape[0] - samples*time_series
X_train_new, X_test_new = X_train.iloc[:start_x], X_train.iloc[start_x:]
# split y_train
start_y = y_train.shape[0] - samples
y_train_new, y_test_new = y_train.iloc[:start_y], y_train.iloc[start_y:]
X_train_new.head(5)
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0       -0.75853       -0.63435
# 1    0_1          0                   1       -0.75853       -0.63434
# 2    0_2          0                   2       -0.75853       -0.63435
# 3    0_3          0                   3       -0.75852       -0.63436
# 4    0_4          0                   4       -0.75852       -0.63435
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.107650            0.017561
# 1       -0.10490       -0.10600            0.067851            0.029939
# 2       -0.10492       -0.10597            0.007275            0.028934
# 3       -0.10495       -0.10597           -0.013053            0.019448
# 4       -0.10495       -0.10596            0.005135            0.007652
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 0            0.000767               -0.74857                 2.1030
# 1            0.003385                0.33995                 1.5064
# 2           -0.005978               -0.26429                 1.5922
# 3           -0.008974                0.42684                 1.0993
# 4            0.005245               -0.50969                 1.4689
#
#    linear_acceleration_Z
# 0                -9.7532
# 1                -9.4128
# 2                -8.7267
# 3               -10.0960
# 4               -10.4410

# %% [markdown]
# As can be noticed, the first 3 columns are not part of the features and must be dropped. We drop these columns for X_train_new and X_test_new.

# %%
X_train_new=X_train_new.drop(['row_id', 'series_id','measurement_number'], axis=1)
X_test_new=X_test_new.drop(['row_id', 'series_id','measurement_number'], axis=1)

# %% [markdown]
# Now, we have a look at the labels of the training data saved in y_train_new. We are only interested in the surface type which is the last column. We drop the other columns from y_train_new.

# %%
y_train_new.head(5)
# Out:
#    series_id  group_id        surface
# 0          0        13  fine_concrete
# 1          1        31       concrete
# 2          2        20       concrete
# 3          3        31       concrete
# 4          4        22     soft_tiles

# %% [markdown]
# We drop the first two columns from the y_train_new and y_test_new as they will not be needed.

# %%
y_train_new=y_train_new.drop(['series_id', 'group_id'], axis=1)
y_test_new=y_test_new.drop(['series_id', 'group_id'], axis=1)

# %% [markdown]
# Now, we convert the dataframes to a numpy array. We extract the values from the data frame using .values. We print the shape of training and testing data.

# %%
X_train_new=X_train_new.values
X_test_new=X_test_new.values
y_train_new=y_train_new.values
y_test_new=y_test_new.values
print('The size of X_train_new:', X_train_new.shape )
print('The size of X_test_new:', X_test_new.shape )

print('The size of y_train_new:', y_train_new.shape )
print('The size of y_test_new:', y_test_new.shape )
# Out:
# The size of X_train_new: (485120, 10)
# The size of X_test_new: (2560, 10)
# The size of y_train_new: (3790, 1)
# The size of y_test_new: (20, 1)

# %% [markdown]
# Now, we convert the strings (concrete, tiled, soft_tiels, ..etc.) in y_train_new and y_test_new to integer labels: 0,1,2... etc using the LabelEncorder function. After that we implement one hot coding using the to_categorical function. We have 9 types of surfaces and thus the number of cloumns for y_train_new and y_test_new  will be 9. One hot coding is suitable for 1D conv net models to prevent poor performance or unexpected results (predictions halfway between categories).

# %%
from keras.utils import to_categorical

labelencoder_y = LabelEncoder()

y=np.concatenate([y_train_new,y_test_new])
y=labelencoder_y.fit_transform(y)
y=to_categorical(y)


y_train_new = y[:-20]
y_test_new = y[-20:]
print('The shape of y_train_new:', y_train_new.shape)
print('The shape of y_test_new:', y_test_new.shape)
# Out:
# The shape of y_train_new: (3790, 9)
# The shape of y_test_new: (20, 9)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# We think that the orientation of the robot moving across surfaces is not a relevant information to predict the surface type. Instead, the rate of change of the roll, yaw and pitch can serve as better features for prediction. The rate of change can be affected by the way the robot moves which is directly affected by the tyoe of surface the robot is moving on. We first calculate the roll, yaw and pitch from the orientation information using the transformation formulas as shown below. We add these features to X_train_new and X_test_new (separately) and delete the orientation features (W,X,Y,Z). The rate of change in yaw,pitch and roll will be calculated at a later step.

# %%
#FOR TRAIN DATASET
roll=np.zeros([X_train_new.shape[0],1])
pitch=np.zeros([X_train_new.shape[0],1])
yaw=np.zeros([X_train_new.shape[0],1])


for i in range(X_train_new.shape[0]):
  roll[i] = np.arctan2(2*(X_train_new[i,1]*X_train_new[i,2] + X_train_new[i,3]*X_train_new[i,0]),1 - 2*(X_train_new[i,2]*X_train_new[i,2] + X_train_new[i,3]*X_train_new[i,3]))
  pitch[i] = np.arcsin(2*(X_train_new[i,1]*X_train_new[i,3] - X_train_new[i,0]*X_train_new[i,2]))
  yaw[i] = np.arctan2(2*(X_train_new[i,1]*X_train_new[i,0] + X_train_new[i,2]*X_train_new[i,3]),1 - 2*(X_train_new[i,3]*X_train_new[i,3] + X_train_new[i,0]*X_train_new[i,0]))

X_train_new=np.delete(X_train_new,[0,1,2,3], 1)
X_train_new=np.concatenate((roll,pitch,yaw,X_train_new),axis=1)

#FOR TEST DATA SET
roll=np.zeros([X_test_new.shape[0],1])
pitch=np.zeros([X_test_new.shape[0],1])
yaw=np.zeros([X_test_new.shape[0],1])


for i in range(X_test_new.shape[0]):
  roll[i] = np.arctan2(2*(X_test_new[i,1]*X_test_new[i,2] + X_test_new[i,3]*X_test_new[i,0]),1 - 2*(X_test_new[i,2]*X_test_new[i,2] + X_test_new[i,3]*X_test_new[i,3]))
  pitch[i] = np.arcsin(2*(X_test_new[i,1]*X_test_new[i,3] - X_test_new[i,0]*X_test_new[i,2]))
  yaw[i] = np.arctan2(2*(X_test_new[i,1]*X_test_new[i,0] + X_test_new[i,2]*X_test_new[i,3]),1 - 2*(X_test_new[i,3]*X_test_new[i,3] + X_test_new[i,0]*X_test_new[i,0]))

X_test_new=np.delete(X_test_new,[0,1,2,3], 1)
X_test_new=np.concatenate((roll,pitch,yaw,X_test_new),axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in arcsin
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in arcsin

# %% [markdown]
# ## **Step 2: Building the model**

# %% [markdown]
# The data should be reshaped in a 3D matrix to suit the 1D CNN input data shape. The first dimension is for the samples, the second for the timestamp, and the third for the featueres.

# %%
nfeatures=X_train_new.shape[1]
ntimestamp=128
nsamples=3790
X_3D_train=X_train_new[:,0].reshape(nsamples,ntimestamp)
for i in range(nfeatures-1):
  i=i+1
  r=X_train_new[:,i].reshape(nsamples,ntimestamp)
  X_3D_train=np.dstack((X_3D_train,r))
print('The shape of X_train: ', X_3D_train.shape)

nfeatures=X_test_new.shape[1]
ntimestamp=128
nsamples=20
X_3D_test=X_test_new[:,0].reshape(nsamples,ntimestamp)
for i in range(nfeatures-1):
  i=i+1
  r=X_test_new[:,i].reshape(nsamples,ntimestamp)
  X_3D_test=np.dstack((X_3D_test,r))
print('The shape of X_test: ', X_3D_test.shape)
# Out:
# The shape of X_train:  (3790, 128, 8)
# The shape of X_test:  (20, 128, 8)

# %% [markdown]
# As mentioned earlier, we need to include the rate of change for the yaw, pitch and roll as they are affected by the type of surface the robot is moving on. We calculated the roll, yaw and pitch earlier and added them to X_train_new and X_test_new. We will replace them with their rate of change instead. They are stored in the first three features.

# %%
for i in range(2):
    rate = X_3D_train[:,:,i]
    rate_c = np.copy(rate)
    rate_c[:,1:] = rate_c[:,:-1]
    rate = rate - rate_c
    X_3D_train[:,:,i] = rate
    
for i in range(2):
    rate = X_3D_test[:,:,i]
    rate_c = np.copy(rate)
    rate_c[:,1:] = rate_c[:,:-1]
    rate = rate - rate_c
    X_3D_test[:,:,i] = rate

# %% [markdown]
# Another feature we think is important is the fft of the time series data. We believe that each surface will cause the robot to vibrate or oscillate with specific frequencies. Thus, we calculate the fft for all the timeseries features in X_train_new and X_test_new (separately) and add the fft of the features to the corresponding matrix.

# %%
from scipy import fftpack
X_3Dfft = np.abs(np.fft.fft(X_3D_train,axis=1))
#freqs = fftpack.fftfreq(len(x)) * f_s
X_3D_train=np.dstack((X_3D_train,X_3Dfft))
print('The size of X_3D: ', X_3D_train.shape)

from scipy import fftpack
X_3Dfft = np.abs(np.fft.fft(X_3D_test,axis=1))
#freqs = fftpack.fftfreq(len(x)) * f_s
X_3D_test=np.dstack((X_3D_test,X_3Dfft))
print('The size of X_3D: ', X_3D_test.shape)
# Out:
# The size of X_3D:  (3790, 128, 18)
# The size of X_3D:  (20, 128, 18)

# %% [markdown]
# We print the parameters of X_train_new. Number of: (features, timestamps and samples)

# %%
nfeatures=X_3D_train.shape[2]
ntimestamp=X_3D_train.shape[1]
nsamples=X_3D_train.shape[0]

print('Number of features in Xtrain: ', nfeatures)
print('Number of timestamps in Xtrain: ', ntimestamp)
print('Number of samples in Xtrain: ', nsamples)
# Out:
# Number of features in Xtrain:  18
# Number of timestamps in Xtrain:  128
# Number of samples in Xtrain:  3790

# %% [markdown]
# We standarize X_train_new and X_test_new separately by calculating the mean and standard deviation for each of the feautures across all samples, and then subtracting the mean and dividing by the standard deviation. Standarization can help the conv net to acheive better results by removing any effects resulted from different recording sessions.

# %%
for k in range(nfeatures):
    X_train_m = np.mean(X_3D_train[:,:,k])
    X_train_sd = np.std(X_3D_train[:,:,k])
    X_3D_train[:,:,k] = (X_3D_train[:,:,k]-X_train_m)/X_train_sd

for k in range(nfeatures):
    X_test_m = np.mean(X_3D_test[:,:,k])
    X_test_sd = np.std(X_3D_test[:,:,k])
    X_3D_test[:,:,k] = (X_3D_test[:,:,k]-X_test_m)/X_test_sd

# %% [markdown]
# Now, we create the 1D convnet model. I have tried to tune the number of layers, number of filters in each layer, the batch size and the dropout ratio to give the best validation accuracy. Removing the 256 filters layer resulted in a very poor accuracy. Adding more layers resulted in overfitting (high accuracy on training data but low on validation). Lower dropout ratio resulted in over fitting too. I added layers one by one and observed how the training and validation accuracy change over training. 15% of the training data is kept for the validation. The high dropout ration is to avoid overfitting during training. Also, I tried to minimize the complexity of the model by introducing enough layers that can achieve the max possible accuracy with the current features created above.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
predict=np.zeros([y_test_new.shape[0],y_test_new.shape[1],3])
for k in range(1):
  verbose, epochs, batch_size = 1, 600, 512
  model = Sequential()
  model.add(Conv1D(filters=64, kernel_size=8, activation='relu', input_shape=(ntimestamp,nfeatures)))
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=128, kernel_size=8, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Conv1D(filters=256, kernel_size=8, activation='relu'))
  model.add(Dropout(0.5))
  model.add(MaxPooling1D(pool_size=1))
  model.add(Flatten())
  model.add(Dense(128, activation='relu')) 
  model.add(Dropout(0.5))
  model.add(Dense(y_train_new.shape[1], activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
  model.fit(X_3D_train, y_train_new, epochs=epochs, batch_size=batch_size, verbose=verbose)
# Out:
# Epoch 1/600
# 8/8 [==============================] - 9s 1s/step - loss: 2.7840 - accuracy: 0.1627
# Epoch 2/600
# 8/8 [==============================] - 9s 1s/step - loss: 2.1552 - accuracy: 0.1914
# Epoch 3/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.9995 - accuracy: 0.2346
# Epoch 4/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.8589 - accuracy: 0.3094
# Epoch 5/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.7470 - accuracy: 0.3789
# Epoch 6/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.6986 - accuracy: 0.3888
# Epoch 7/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.6149 - accuracy: 0.4094
# Epoch 8/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.5914 - accuracy: 0.4231
# Epoch 9/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.5636 - accuracy: 0.4386
# Epoch 10/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.5442 - accuracy: 0.4416
# Epoch 11/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.4864 - accuracy: 0.4527
# Epoch 12/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.4707 - accuracy: 0.4688
# Epoch 13/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.4389 - accuracy: 0.4726
# Epoch 14/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.4031 - accuracy: 0.4876
# Epoch 15/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.3860 - accuracy: 0.4847
# Epoch 16/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.3455 - accuracy: 0.5082
# Epoch 17/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.3029 - accuracy: 0.5155
# Epoch 18/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.3197 - accuracy: 0.5195
# Epoch 19/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.2650 - accuracy: 0.5316
# Epoch 20/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.2038 - accuracy: 0.5528
# Epoch 21/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.1434 - accuracy: 0.5820
# Epoch 22/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.0970 - accuracy: 0.5940
# Epoch 23/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.0599 - accuracy: 0.6055
# Epoch 24/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.0589 - accuracy: 0.6361
# Epoch 25/600
# 8/8 [==============================] - 9s 1s/step - loss: 1.0198 - accuracy: 0.6213
# Epoch 26/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.9873 - accuracy: 0.6463
# Epoch 27/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.9803 - accuracy: 0.6343
# Epoch 28/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.9289 - accuracy: 0.6538
# Epoch 29/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.9162 - accuracy: 0.6573
# Epoch 30/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.8963 - accuracy: 0.6843
# Epoch 31/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.8379 - accuracy: 0.6904
# Epoch 32/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.8246 - accuracy: 0.6847
# Epoch 33/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.8053 - accuracy: 0.7011
# Epoch 34/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.7691 - accuracy: 0.7193
# Epoch 35/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.7678 - accuracy: 0.7246
# Epoch 36/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.7506 - accuracy: 0.7195
# Epoch 37/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.7240 - accuracy: 0.7309
# Epoch 38/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.6615 - accuracy: 0.7497
# Epoch 39/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.6646 - accuracy: 0.7529
# Epoch 40/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.6614 - accuracy: 0.7568
# Epoch 41/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5978 - accuracy: 0.7814
# Epoch 42/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5960 - accuracy: 0.7821
# Epoch 43/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5973 - accuracy: 0.7795
# Epoch 44/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5681 - accuracy: 0.7895
# Epoch 45/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5449 - accuracy: 0.8082
# Epoch 46/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5146 - accuracy: 0.8152
# Epoch 47/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5327 - accuracy: 0.8101
# Epoch 48/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5033 - accuracy: 0.8126
# Epoch 49/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.5225 - accuracy: 0.8019
# Epoch 50/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4873 - accuracy: 0.8254
# Epoch 51/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4669 - accuracy: 0.8277
# Epoch 52/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4483 - accuracy: 0.8277
# Epoch 53/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4290 - accuracy: 0.8341
# Epoch 54/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4385 - accuracy: 0.8392
# Epoch 55/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4005 - accuracy: 0.8462
# Epoch 56/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4193 - accuracy: 0.8432
# Epoch 57/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4087 - accuracy: 0.8411
# Epoch 58/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.4022 - accuracy: 0.8430
# Epoch 59/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3610 - accuracy: 0.8651
# Epoch 60/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3518 - accuracy: 0.8691
# Epoch 61/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3564 - accuracy: 0.8742
# Epoch 62/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3392 - accuracy: 0.8795
# Epoch 63/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3520 - accuracy: 0.8653
# Epoch 64/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3439 - accuracy: 0.8672
# Epoch 65/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3382 - accuracy: 0.8718
# Epoch 66/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3639 - accuracy: 0.8600
# Epoch 67/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3481 - accuracy: 0.8705
# Epoch 68/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3277 - accuracy: 0.8743
# Epoch 69/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.3473 - accuracy: 0.8647
# Epoch 70/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3314 - accuracy: 0.8686
# Epoch 71/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2980 - accuracy: 0.8891
# Epoch 72/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3028 - accuracy: 0.8860
# Epoch 73/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3021 - accuracy: 0.8853
# Epoch 74/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2781 - accuracy: 0.8908
# Epoch 75/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2957 - accuracy: 0.8885
# Epoch 76/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2878 - accuracy: 0.8859
# Epoch 77/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.3144 - accuracy: 0.8735
# Epoch 78/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2622 - accuracy: 0.8997
# Epoch 79/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2654 - accuracy: 0.9014
# Epoch 80/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2464 - accuracy: 0.9087
# Epoch 81/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2374 - accuracy: 0.9034
# Epoch 82/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2390 - accuracy: 0.9151
# Epoch 83/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2529 - accuracy: 0.9032
# Epoch 84/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2490 - accuracy: 0.8974
# Epoch 85/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2294 - accuracy: 0.9168
# Epoch 86/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2538 - accuracy: 0.9025
# Epoch 87/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2293 - accuracy: 0.9138
# Epoch 88/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2348 - accuracy: 0.9078
# Epoch 89/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2272 - accuracy: 0.9080
# Epoch 90/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2267 - accuracy: 0.9077
# Epoch 91/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2289 - accuracy: 0.9122
# Epoch 92/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2077 - accuracy: 0.9263
# Epoch 93/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2284 - accuracy: 0.9173
# Epoch 94/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2218 - accuracy: 0.9129
# Epoch 95/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2228 - accuracy: 0.9165
# Epoch 96/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2181 - accuracy: 0.9140
# Epoch 97/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1988 - accuracy: 0.9247
# Epoch 98/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2005 - accuracy: 0.9233
# Epoch 99/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1928 - accuracy: 0.9258
# Epoch 100/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2267 - accuracy: 0.9215
# Epoch 101/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1954 - accuracy: 0.9262
# Epoch 102/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1740 - accuracy: 0.9426
# Epoch 103/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.2105 - accuracy: 0.9208
# Epoch 104/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1942 - accuracy: 0.9270
# Epoch 105/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1896 - accuracy: 0.9270
# Epoch 106/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1968 - accuracy: 0.9231
# Epoch 107/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1928 - accuracy: 0.9278
# Epoch 108/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1757 - accuracy: 0.9290
# Epoch 109/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1857 - accuracy: 0.9315
# Epoch 110/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1836 - accuracy: 0.9317
# Epoch 111/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1786 - accuracy: 0.9280
# Epoch 112/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1770 - accuracy: 0.9290
# Epoch 113/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1870 - accuracy: 0.9284
# Epoch 114/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1702 - accuracy: 0.9346
# Epoch 115/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1666 - accuracy: 0.9400
# Epoch 116/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1832 - accuracy: 0.9327
# Epoch 117/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1752 - accuracy: 0.9371
# Epoch 118/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1615 - accuracy: 0.9430
# Epoch 119/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1531 - accuracy: 0.9454
# Epoch 120/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1532 - accuracy: 0.9403
# Epoch 121/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1575 - accuracy: 0.9353
# Epoch 122/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1525 - accuracy: 0.9451
# Epoch 123/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1459 - accuracy: 0.9445
# Epoch 124/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1607 - accuracy: 0.9423
# Epoch 125/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1798 - accuracy: 0.9312
# Epoch 126/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1724 - accuracy: 0.9340
# Epoch 127/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1551 - accuracy: 0.9415
# Epoch 128/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1512 - accuracy: 0.9411
# Epoch 129/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1515 - accuracy: 0.9445
# Epoch 130/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1597 - accuracy: 0.9361
# Epoch 131/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1498 - accuracy: 0.9424
# Epoch 132/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1801 - accuracy: 0.9437
# Epoch 133/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1455 - accuracy: 0.9415
# Epoch 134/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1673 - accuracy: 0.9390
# Epoch 135/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1621 - accuracy: 0.9409
# Epoch 136/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1546 - accuracy: 0.9469
# Epoch 137/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1491 - accuracy: 0.9487
# Epoch 138/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1474 - accuracy: 0.9400
# Epoch 139/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1444 - accuracy: 0.9379
# Epoch 140/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1501 - accuracy: 0.9420
# Epoch 141/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1529 - accuracy: 0.9438
# Epoch 142/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1613 - accuracy: 0.9363
# Epoch 143/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1349 - accuracy: 0.9464
# Epoch 144/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1498 - accuracy: 0.9479
# Epoch 145/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1202 - accuracy: 0.9561
# Epoch 146/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1409 - accuracy: 0.9482
# Epoch 147/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1116 - accuracy: 0.9586
# Epoch 148/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1529 - accuracy: 0.9446
# Epoch 149/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1274 - accuracy: 0.9515
# Epoch 150/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1294 - accuracy: 0.9508
# Epoch 151/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1315 - accuracy: 0.9524
# Epoch 152/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1281 - accuracy: 0.9498
# Epoch 153/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1352 - accuracy: 0.9419
# Epoch 154/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1389 - accuracy: 0.9414
# Epoch 155/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1238 - accuracy: 0.9519
# Epoch 156/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1599 - accuracy: 0.9421
# Epoch 157/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1359 - accuracy: 0.9458
# Epoch 158/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1368 - accuracy: 0.9524
# Epoch 159/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1293 - accuracy: 0.9533
# Epoch 160/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1253 - accuracy: 0.9543
# Epoch 161/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1176 - accuracy: 0.9532
# Epoch 162/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1122 - accuracy: 0.9563
# Epoch 163/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.1310 - accuracy: 0.9525
# Epoch 164/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1293 - accuracy: 0.9497
# Epoch 165/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1328 - accuracy: 0.9447
# Epoch 166/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1134 - accuracy: 0.9560
# Epoch 167/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1148 - accuracy: 0.9579
# Epoch 168/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1240 - accuracy: 0.9548
# Epoch 169/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1116 - accuracy: 0.9592
# Epoch 170/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1245 - accuracy: 0.9550
# Epoch 171/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1209 - accuracy: 0.9535
# Epoch 172/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1185 - accuracy: 0.9547
# Epoch 173/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1257 - accuracy: 0.9517
# Epoch 174/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1200 - accuracy: 0.9633
# Epoch 175/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1090 - accuracy: 0.9550
# Epoch 176/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1106 - accuracy: 0.9578
# Epoch 177/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1135 - accuracy: 0.9596
# Epoch 178/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0967 - accuracy: 0.9591
# Epoch 179/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1020 - accuracy: 0.9606
# Epoch 180/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1091 - accuracy: 0.9613
# Epoch 181/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1059 - accuracy: 0.9612
# Epoch 182/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1162 - accuracy: 0.9544
# Epoch 183/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1038 - accuracy: 0.9582
# Epoch 184/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.1157 - accuracy: 0.9568
# Epoch 185/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1091 - accuracy: 0.9561
# Epoch 186/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0978 - accuracy: 0.9604
# Epoch 187/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0951 - accuracy: 0.9660
# Epoch 188/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1139 - accuracy: 0.9590
# Epoch 189/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0863 - accuracy: 0.9674
# Epoch 190/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1037 - accuracy: 0.9603
# Epoch 191/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1082 - accuracy: 0.9594
# Epoch 192/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0928 - accuracy: 0.9604
# Epoch 193/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0997 - accuracy: 0.9649
# Epoch 194/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0920 - accuracy: 0.9633
# Epoch 195/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0876 - accuracy: 0.9642
# Epoch 196/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0931 - accuracy: 0.9646
# Epoch 197/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1002 - accuracy: 0.9639
# Epoch 198/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1087 - accuracy: 0.9581
# Epoch 199/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1095 - accuracy: 0.9591
# Epoch 200/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0950 - accuracy: 0.9630
# Epoch 201/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0936 - accuracy: 0.9659
# Epoch 202/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.1024 - accuracy: 0.9642
# Epoch 203/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0901 - accuracy: 0.9656
# Epoch 204/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0926 - accuracy: 0.9657
# Epoch 205/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.1024 - accuracy: 0.9630
# Epoch 206/600
# 8/8 [==============================] - 11s 1s/step - loss: 0.0943 - accuracy: 0.9668
# Epoch 207/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.1047 - accuracy: 0.9614
# Epoch 208/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0933 - accuracy: 0.9659
# Epoch 209/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1008 - accuracy: 0.9641
# Epoch 210/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0913 - accuracy: 0.9631
# Epoch 211/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0838 - accuracy: 0.9707
# Epoch 212/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0966 - accuracy: 0.9659
# Epoch 213/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1021 - accuracy: 0.9650
# Epoch 214/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0827 - accuracy: 0.9673
# Epoch 215/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0833 - accuracy: 0.9705
# Epoch 216/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0934 - accuracy: 0.9672
# Epoch 217/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1169 - accuracy: 0.9565
# Epoch 218/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1041 - accuracy: 0.9574
# Epoch 219/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0997 - accuracy: 0.9646
# Epoch 220/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1057 - accuracy: 0.9626
# Epoch 221/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0859 - accuracy: 0.9646
# Epoch 222/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0828 - accuracy: 0.9699
# Epoch 223/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0880 - accuracy: 0.9653
# Epoch 224/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0781 - accuracy: 0.9694
# Epoch 225/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0886 - accuracy: 0.9672
# Epoch 226/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0875 - accuracy: 0.9652
# Epoch 227/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1062 - accuracy: 0.9632
# Epoch 228/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0977 - accuracy: 0.9608
# Epoch 229/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0938 - accuracy: 0.9638
# Epoch 230/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0965 - accuracy: 0.9638
# Epoch 231/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0757 - accuracy: 0.9707
# Epoch 232/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1021 - accuracy: 0.9620
# Epoch 233/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0935 - accuracy: 0.9652
# Epoch 234/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0850 - accuracy: 0.9657
# Epoch 235/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0721 - accuracy: 0.9706
# Epoch 236/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0865 - accuracy: 0.9647
# Epoch 237/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0849 - accuracy: 0.9662
# Epoch 238/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0794 - accuracy: 0.9733
# Epoch 239/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0768 - accuracy: 0.9702
# Epoch 240/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0806 - accuracy: 0.9719
# Epoch 241/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0834 - accuracy: 0.9682
# Epoch 242/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0840 - accuracy: 0.9732
# Epoch 243/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0747 - accuracy: 0.9726
# Epoch 244/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0808 - accuracy: 0.9701
# Epoch 245/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1001 - accuracy: 0.9601
# Epoch 246/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1052 - accuracy: 0.9615
# Epoch 247/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0864 - accuracy: 0.9667
# Epoch 248/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0749 - accuracy: 0.9694
# Epoch 249/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0745 - accuracy: 0.9726
# Epoch 250/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0721 - accuracy: 0.9709
# Epoch 251/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0812 - accuracy: 0.9713
# Epoch 252/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0726 - accuracy: 0.9665
# Epoch 253/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0947 - accuracy: 0.9654
# Epoch 254/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0799 - accuracy: 0.9666
# Epoch 255/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0753 - accuracy: 0.9712
# Epoch 256/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0733 - accuracy: 0.9747
# Epoch 257/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0794 - accuracy: 0.9719
# Epoch 258/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0967 - accuracy: 0.9650
# Epoch 259/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0766 - accuracy: 0.9696
# Epoch 260/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0608 - accuracy: 0.9774
# Epoch 261/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0776 - accuracy: 0.9718
# Epoch 262/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0766 - accuracy: 0.9730
# Epoch 263/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0872 - accuracy: 0.9697
# Epoch 264/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0928 - accuracy: 0.9661
# Epoch 265/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0891 - accuracy: 0.9679
# Epoch 266/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0876 - accuracy: 0.9681
# Epoch 267/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0844 - accuracy: 0.9682
# Epoch 268/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0745 - accuracy: 0.9754
# Epoch 269/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0961 - accuracy: 0.9672
# Epoch 270/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0838 - accuracy: 0.9715
# Epoch 271/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0725 - accuracy: 0.9721
# Epoch 272/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0763 - accuracy: 0.9696
# Epoch 273/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0740 - accuracy: 0.9780
# Epoch 274/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0804 - accuracy: 0.9709
# Epoch 275/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0737 - accuracy: 0.9709
# Epoch 276/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0683 - accuracy: 0.9745
# Epoch 277/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0589 - accuracy: 0.9767
# Epoch 278/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0552 - accuracy: 0.9797
# Epoch 279/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0719 - accuracy: 0.9745
# Epoch 280/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0756 - accuracy: 0.9700
# Epoch 281/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0686 - accuracy: 0.9717
# Epoch 282/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0682 - accuracy: 0.9760
# Epoch 283/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0733 - accuracy: 0.9732
# Epoch 284/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0718 - accuracy: 0.9769
# Epoch 285/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0710 - accuracy: 0.9713
# Epoch 286/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0727 - accuracy: 0.9734
# Epoch 287/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0722 - accuracy: 0.9713
# Epoch 288/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0778 - accuracy: 0.9714
# Epoch 289/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0716 - accuracy: 0.9740
# Epoch 290/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0777 - accuracy: 0.9742
# Epoch 291/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0906 - accuracy: 0.9687
# Epoch 292/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0811 - accuracy: 0.9693
# Epoch 293/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0748 - accuracy: 0.9696
# Epoch 294/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0835 - accuracy: 0.9693
# Epoch 295/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0741 - accuracy: 0.9757
# Epoch 296/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0718 - accuracy: 0.9717
# Epoch 297/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0715 - accuracy: 0.9779
# Epoch 298/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0669 - accuracy: 0.9761
# Epoch 299/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0663 - accuracy: 0.9732
# Epoch 300/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0620 - accuracy: 0.9766
# Epoch 301/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0558 - accuracy: 0.9782
# Epoch 302/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0613 - accuracy: 0.9772
# Epoch 303/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0577 - accuracy: 0.9779
# Epoch 304/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0633 - accuracy: 0.9779
# Epoch 305/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0507 - accuracy: 0.9801
# Epoch 306/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0561 - accuracy: 0.9790
# Epoch 307/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0486 - accuracy: 0.9805
# Epoch 308/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0527 - accuracy: 0.9805
# Epoch 309/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0727 - accuracy: 0.9760
# Epoch 310/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0411 - accuracy: 0.9839
# Epoch 311/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0566 - accuracy: 0.9800
# Epoch 312/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0504 - accuracy: 0.9822
# Epoch 313/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0679 - accuracy: 0.9786
# Epoch 314/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0691 - accuracy: 0.9762
# Epoch 315/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0740 - accuracy: 0.9747
# Epoch 316/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0681 - accuracy: 0.9759
# Epoch 317/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0704 - accuracy: 0.9752
# Epoch 318/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0644 - accuracy: 0.9758
# Epoch 319/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0563 - accuracy: 0.9772
# Epoch 320/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0567 - accuracy: 0.9772
# Epoch 321/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0551 - accuracy: 0.9811
# Epoch 322/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0573 - accuracy: 0.9769
# Epoch 323/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0529 - accuracy: 0.9851
# Epoch 324/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0428 - accuracy: 0.9852
# Epoch 325/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0581 - accuracy: 0.9791
# Epoch 326/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0425 - accuracy: 0.9851
# Epoch 327/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0543 - accuracy: 0.9780
# Epoch 328/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0515 - accuracy: 0.9778
# Epoch 329/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0624 - accuracy: 0.9795
# Epoch 330/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0514 - accuracy: 0.9811
# Epoch 331/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.1036 - accuracy: 0.9692
# Epoch 332/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0628 - accuracy: 0.9792
# Epoch 333/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0824 - accuracy: 0.9712
# Epoch 334/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0602 - accuracy: 0.9789
# Epoch 335/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0614 - accuracy: 0.9806
# Epoch 336/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0547 - accuracy: 0.9800
# Epoch 337/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0604 - accuracy: 0.9814
# Epoch 338/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0709 - accuracy: 0.9743
# Epoch 339/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0751 - accuracy: 0.9771
# Epoch 340/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0702 - accuracy: 0.9746
# Epoch 341/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0685 - accuracy: 0.9790
# Epoch 342/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0533 - accuracy: 0.9805
# Epoch 343/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0459 - accuracy: 0.9839
# Epoch 344/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0604 - accuracy: 0.9802
# Epoch 345/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0441 - accuracy: 0.9837
# Epoch 346/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0546 - accuracy: 0.9820
# Epoch 347/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0473 - accuracy: 0.9810
# Epoch 348/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0577 - accuracy: 0.9756
# Epoch 349/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0444 - accuracy: 0.9830
# Epoch 350/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0659 - accuracy: 0.9760
# Epoch 351/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0702 - accuracy: 0.9766
# Epoch 352/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0520 - accuracy: 0.9783
# Epoch 353/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0518 - accuracy: 0.9803
# Epoch 354/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0610 - accuracy: 0.9769
# Epoch 355/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0549 - accuracy: 0.9788
# Epoch 356/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0657 - accuracy: 0.9757
# Epoch 357/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0587 - accuracy: 0.9776
# Epoch 358/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0718 - accuracy: 0.9760
# Epoch 359/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0667 - accuracy: 0.9792
# Epoch 360/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0617 - accuracy: 0.9791
# Epoch 361/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0539 - accuracy: 0.9812
# Epoch 362/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0555 - accuracy: 0.9804
# Epoch 363/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0577 - accuracy: 0.9811
# Epoch 364/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0574 - accuracy: 0.9816
# Epoch 365/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0729 - accuracy: 0.9796
# Epoch 366/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0616 - accuracy: 0.9753
# Epoch 367/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0676 - accuracy: 0.9779
# Epoch 368/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0571 - accuracy: 0.9794
# Epoch 369/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0596 - accuracy: 0.9795
# Epoch 370/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0510 - accuracy: 0.9800
# Epoch 371/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0687 - accuracy: 0.9786
# Epoch 372/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0466 - accuracy: 0.9827
# Epoch 373/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0647 - accuracy: 0.9769
# Epoch 374/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0565 - accuracy: 0.9779
# Epoch 375/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0459 - accuracy: 0.9827
# Epoch 376/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0585 - accuracy: 0.9796
# Epoch 377/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0429 - accuracy: 0.9823
# Epoch 378/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0526 - accuracy: 0.9790
# Epoch 379/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0576 - accuracy: 0.9825
# Epoch 380/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0632 - accuracy: 0.9790
# Epoch 381/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0634 - accuracy: 0.9773
# Epoch 382/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0553 - accuracy: 0.9800
# Epoch 383/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0581 - accuracy: 0.9799
# Epoch 384/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0460 - accuracy: 0.9835
# Epoch 385/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0494 - accuracy: 0.9827
# Epoch 386/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0530 - accuracy: 0.9831
# Epoch 387/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0466 - accuracy: 0.9812
# Epoch 388/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0622 - accuracy: 0.9803
# Epoch 389/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0659 - accuracy: 0.9771
# Epoch 390/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0568 - accuracy: 0.9785
# Epoch 391/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0676 - accuracy: 0.9758
# Epoch 392/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0586 - accuracy: 0.9802
# Epoch 393/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0538 - accuracy: 0.9808
# Epoch 394/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0620 - accuracy: 0.9815
# Epoch 395/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0529 - accuracy: 0.9828
# Epoch 396/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0606 - accuracy: 0.9782
# Epoch 397/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0412 - accuracy: 0.9867
# Epoch 398/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0444 - accuracy: 0.9846
# Epoch 399/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0482 - accuracy: 0.9805
# Epoch 400/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0517 - accuracy: 0.9813
# Epoch 401/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0667 - accuracy: 0.9816
# Epoch 402/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0752 - accuracy: 0.9765
# Epoch 403/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0713 - accuracy: 0.9721
# Epoch 404/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0722 - accuracy: 0.9777
# Epoch 405/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0501 - accuracy: 0.9825
# Epoch 406/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0562 - accuracy: 0.9815
# Epoch 407/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0690 - accuracy: 0.9707
# Epoch 408/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0563 - accuracy: 0.9784
# Epoch 409/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0462 - accuracy: 0.9827
# Epoch 410/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0530 - accuracy: 0.9856
# Epoch 411/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0594 - accuracy: 0.9807
# Epoch 412/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0488 - accuracy: 0.9809
# Epoch 413/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0452 - accuracy: 0.9846
# Epoch 414/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0646 - accuracy: 0.9780
# Epoch 415/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0447 - accuracy: 0.9855
# Epoch 416/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0363 - accuracy: 0.9862
# Epoch 417/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0415 - accuracy: 0.9833
# Epoch 418/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0463 - accuracy: 0.9815
# Epoch 419/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0420 - accuracy: 0.9844
# Epoch 420/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0501 - accuracy: 0.9831
# Epoch 421/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0519 - accuracy: 0.9856
# Epoch 422/600
# 8/8 [==============================] - 11s 1s/step - loss: 0.0596 - accuracy: 0.9770
# Epoch 423/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0558 - accuracy: 0.9792
# Epoch 424/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0598 - accuracy: 0.9823
# Epoch 425/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0695 - accuracy: 0.9760
# Epoch 426/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0595 - accuracy: 0.9804
# Epoch 427/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0412 - accuracy: 0.9856
# Epoch 428/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0445 - accuracy: 0.9847
# Epoch 429/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0603 - accuracy: 0.9808
# Epoch 430/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0401 - accuracy: 0.9850
# Epoch 431/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0536 - accuracy: 0.9815
# Epoch 432/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0380 - accuracy: 0.9883
# Epoch 433/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0515 - accuracy: 0.9821
# Epoch 434/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0524 - accuracy: 0.9787
# Epoch 435/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0407 - accuracy: 0.9860
# Epoch 436/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0449 - accuracy: 0.9842
# Epoch 437/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0530 - accuracy: 0.9817
# Epoch 438/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0482 - accuracy: 0.9838
# Epoch 439/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0498 - accuracy: 0.9828
# Epoch 440/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0391 - accuracy: 0.9859
# Epoch 441/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0512 - accuracy: 0.9806
# Epoch 442/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0498 - accuracy: 0.9809
# Epoch 443/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0438 - accuracy: 0.9819
# Epoch 444/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0353 - accuracy: 0.9870
# Epoch 445/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0373 - accuracy: 0.9875
# Epoch 446/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0378 - accuracy: 0.9869
# Epoch 447/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0439 - accuracy: 0.9831
# Epoch 448/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0465 - accuracy: 0.9831
# Epoch 449/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0643 - accuracy: 0.9811
# Epoch 450/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0563 - accuracy: 0.9789
# Epoch 451/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0480 - accuracy: 0.9816
# Epoch 452/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0453 - accuracy: 0.9845
# Epoch 453/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0507 - accuracy: 0.9785
# Epoch 454/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0405 - accuracy: 0.9837
# Epoch 455/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0383 - accuracy: 0.9869
# Epoch 456/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0396 - accuracy: 0.9857
# Epoch 457/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0419 - accuracy: 0.9835
# Epoch 458/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0447 - accuracy: 0.9843
# Epoch 459/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0529 - accuracy: 0.9844
# Epoch 460/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0559 - accuracy: 0.9829
# Epoch 461/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0536 - accuracy: 0.9833
# Epoch 462/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0430 - accuracy: 0.9823
# Epoch 463/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0443 - accuracy: 0.9841
# Epoch 464/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0628 - accuracy: 0.9828
# Epoch 465/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0397 - accuracy: 0.9831
# Epoch 466/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0554 - accuracy: 0.9804
# Epoch 467/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0466 - accuracy: 0.9835
# Epoch 468/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0479 - accuracy: 0.9846
# Epoch 469/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0504 - accuracy: 0.9815
# Epoch 470/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0442 - accuracy: 0.9855
# Epoch 471/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0430 - accuracy: 0.9837
# Epoch 472/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0381 - accuracy: 0.9851
# Epoch 473/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0366 - accuracy: 0.9889
# Epoch 474/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0437 - accuracy: 0.9840
# Epoch 475/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0491 - accuracy: 0.9858
# Epoch 476/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0321 - accuracy: 0.9875
# Epoch 477/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0423 - accuracy: 0.9833
# Epoch 478/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0453 - accuracy: 0.9837
# Epoch 479/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0470 - accuracy: 0.9857
# Epoch 480/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0595 - accuracy: 0.9801
# Epoch 481/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0556 - accuracy: 0.9802
# Epoch 482/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0450 - accuracy: 0.9844
# Epoch 483/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0474 - accuracy: 0.9840
# Epoch 484/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0477 - accuracy: 0.9815
# Epoch 485/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0464 - accuracy: 0.9850
# Epoch 486/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0498 - accuracy: 0.9816
# Epoch 487/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0674 - accuracy: 0.9816
# Epoch 488/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0738 - accuracy: 0.9772
# Epoch 489/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0569 - accuracy: 0.9851
# Epoch 490/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0559 - accuracy: 0.9812
# Epoch 491/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0541 - accuracy: 0.9808
# Epoch 492/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0589 - accuracy: 0.9792
# Epoch 493/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0511 - accuracy: 0.9787
# Epoch 494/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0510 - accuracy: 0.9841
# Epoch 495/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0642 - accuracy: 0.9809
# Epoch 496/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0535 - accuracy: 0.9817
# Epoch 497/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0459 - accuracy: 0.9843
# Epoch 498/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0473 - accuracy: 0.9834
# Epoch 499/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0486 - accuracy: 0.9806
# Epoch 500/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0494 - accuracy: 0.9795
# Epoch 501/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0379 - accuracy: 0.9872
# Epoch 502/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0512 - accuracy: 0.9849
# Epoch 503/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0374 - accuracy: 0.9870
# Epoch 504/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0600 - accuracy: 0.9784
# Epoch 505/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0520 - accuracy: 0.9817
# Epoch 506/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0331 - accuracy: 0.9873
# Epoch 507/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0412 - accuracy: 0.9849
# Epoch 508/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0428 - accuracy: 0.9832
# Epoch 509/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0459 - accuracy: 0.9856
# Epoch 510/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0410 - accuracy: 0.9862
# Epoch 511/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0530 - accuracy: 0.9789
# Epoch 512/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0505 - accuracy: 0.9842
# Epoch 513/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0531 - accuracy: 0.9802
# Epoch 514/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0415 - accuracy: 0.9854
# Epoch 515/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0431 - accuracy: 0.9871
# Epoch 516/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0379 - accuracy: 0.9871
# Epoch 517/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0422 - accuracy: 0.9850
# Epoch 518/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0456 - accuracy: 0.9836
# Epoch 519/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0447 - accuracy: 0.9866
# Epoch 520/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0351 - accuracy: 0.9901
# Epoch 521/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0470 - accuracy: 0.9856
# Epoch 522/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0404 - accuracy: 0.9867
# Epoch 523/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0477 - accuracy: 0.9837
# Epoch 524/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0471 - accuracy: 0.9824
# Epoch 525/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0472 - accuracy: 0.9834
# Epoch 526/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0363 - accuracy: 0.9897
# Epoch 527/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0421 - accuracy: 0.9881
# Epoch 528/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0496 - accuracy: 0.9855
# Epoch 529/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0393 - accuracy: 0.9854
# Epoch 530/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0461 - accuracy: 0.9834
# Epoch 531/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0513 - accuracy: 0.9831
# Epoch 532/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0464 - accuracy: 0.9836
# Epoch 533/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0465 - accuracy: 0.9829
# Epoch 534/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0473 - accuracy: 0.9842
# Epoch 535/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0428 - accuracy: 0.9853
# Epoch 536/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0501 - accuracy: 0.9826
# Epoch 537/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0507 - accuracy: 0.9865
# Epoch 538/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0428 - accuracy: 0.9861
# Epoch 539/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0370 - accuracy: 0.9860
# Epoch 540/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0488 - accuracy: 0.9844
# Epoch 541/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0306 - accuracy: 0.9909
# Epoch 542/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0450 - accuracy: 0.9826
# Epoch 543/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0433 - accuracy: 0.9864
# Epoch 544/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0463 - accuracy: 0.9873
# Epoch 545/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0399 - accuracy: 0.9836
# Epoch 546/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0392 - accuracy: 0.9861
# Epoch 547/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0442 - accuracy: 0.9859
# Epoch 548/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0360 - accuracy: 0.9845
# Epoch 549/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0262 - accuracy: 0.9899
# Epoch 550/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0505 - accuracy: 0.9837
# Epoch 551/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0424 - accuracy: 0.9841
# Epoch 552/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0433 - accuracy: 0.9834
# Epoch 553/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0461 - accuracy: 0.9871
# Epoch 554/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0386 - accuracy: 0.9837
# Epoch 555/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0399 - accuracy: 0.9867
# Epoch 556/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0356 - accuracy: 0.9867
# Epoch 557/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0337 - accuracy: 0.9892
# Epoch 558/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0498 - accuracy: 0.9840
# Epoch 559/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0386 - accuracy: 0.9875
# Epoch 560/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0416 - accuracy: 0.9854
# Epoch 561/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0458 - accuracy: 0.9866
# Epoch 562/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0351 - accuracy: 0.9882
# Epoch 563/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0467 - accuracy: 0.9825
# Epoch 564/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0267 - accuracy: 0.9913
# Epoch 565/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0385 - accuracy: 0.9853
# Epoch 566/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0527 - accuracy: 0.9843
# Epoch 567/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0590 - accuracy: 0.9789
# Epoch 568/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0404 - accuracy: 0.9842
# Epoch 569/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0466 - accuracy: 0.9843
# Epoch 570/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0380 - accuracy: 0.9885
# Epoch 571/600
# 8/8 [==============================] - 10s 1s/step - loss: 0.0373 - accuracy: 0.9871
# Epoch 572/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0322 - accuracy: 0.9861
# Epoch 573/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0291 - accuracy: 0.9880
# Epoch 574/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0454 - accuracy: 0.9872
# Epoch 575/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0532 - accuracy: 0.9828
# Epoch 576/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0386 - accuracy: 0.9849
# Epoch 577/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0358 - accuracy: 0.9894
# Epoch 578/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0491 - accuracy: 0.9826
# Epoch 579/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0306 - accuracy: 0.9881
# Epoch 580/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0357 - accuracy: 0.9883
# Epoch 581/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0356 - accuracy: 0.9876
# Epoch 582/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0320 - accuracy: 0.9871
# Epoch 583/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0470 - accuracy: 0.9826
# Epoch 584/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0396 - accuracy: 0.9834
# Epoch 585/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0468 - accuracy: 0.9836
# Epoch 586/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0400 - accuracy: 0.9883
# Epoch 587/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0357 - accuracy: 0.9875
# Epoch 588/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0452 - accuracy: 0.9826
# Epoch 589/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0477 - accuracy: 0.9818
# Epoch 590/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0439 - accuracy: 0.9828
# Epoch 591/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0420 - accuracy: 0.9856
# Epoch 592/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0462 - accuracy: 0.9843
# Epoch 593/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0443 - accuracy: 0.9841
# Epoch 594/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0344 - accuracy: 0.9896
# Epoch 595/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0390 - accuracy: 0.9861
# Epoch 596/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0523 - accuracy: 0.9835
# Epoch 597/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0446 - accuracy: 0.9857
# Epoch 598/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0413 - accuracy: 0.9862
# Epoch 599/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0382 - accuracy: 0.9871
# Epoch 600/600
# 8/8 [==============================] - 9s 1s/step - loss: 0.0388 - accuracy: 0.9854

# %% [markdown]
# We calculate the accuracy by comparing the prediction vs ytest:

# %%
# evaluate model
predict=np.zeros([y_test_new.shape[0],y_test_new.shape[1],3])

yhat=model.predict(X_3D_test)
predict[:,:,k]=yhat

#_, accuracy = model.evaluate(testX, testy, batch_size=batch_size, verbose=0)

yhat=np.mean(predict,axis=2)
yhat_final = np.array(list(np.argmax(yhat,axis=1)))
y_testt=np.argmax(y_test_new,axis=1)

accuracy=np.mean(yhat_final==y_testt)
print('The accuracy is:', accuracy)
# Out:
# The accuracy is: 0.8

# %%
from keras.models import load_model
model.save('my_model.h5')

# %%
from keras.models import load_model
model.save('C:\\data/my_model2.h5')

# %%
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: d:\temp\tmpwcrz5bg4\assets

# %%
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
model = load_model(model.tflite)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-2d195e451a94> in <module>
# ----> 1 model1 = load_model(model.tflite)
#
# AttributeError: 'Sequential' object has no attribute 'tflite'
